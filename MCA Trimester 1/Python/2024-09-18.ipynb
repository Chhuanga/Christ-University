# %%
import matplotlib.pyplot as plt
import numpy as np
x = [10, 20, 30, 40]
y = [20, 25, 35, 55]
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
plt.plot(x,y)
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('Line graph')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 6
#       4 plt.title('Line graph')
#       5 plt.show()
# ----> 6 x=np.arrange(0, 10*np.pi,0.1)
#       7 y=np.sin(x)
#       8 plt.plot(x,y, color="green")
#
# File c:\Users\Moksh\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\__init__.py:428, in __getattr__(attr)
#     425     import numpy.char as char
#     426     return char.chararray
# --> 428 raise AttributeError("module {!r} has no attribute "
#     429                      "{!r}".format(__name__, attr))
#
# AttributeError: module 'numpy' has no attribute 'arrange'

# %%
x=np.arange(0, 10*np.pi, 0.1)
y=np.sin(x)
plt.plot(x,y, color="green")

# %%
data={'C':20, 'C++':15, 'Java':30, 'Python':35}
x=list(data.keys())
y=list(data.values())

fig=plt.figure(figsize=(10,5))
plt.bar(x,y, color='orange')
plt.xlabel('Languages')
plt.ylabel('No. of students')
plt.title('Programming languages')
plt.show()
